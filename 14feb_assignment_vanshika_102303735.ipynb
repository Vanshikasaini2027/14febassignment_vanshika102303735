# %%
# !pip install yt-dlp pydub
# !apt-get install ffmpeg -y
# Out:
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (2026.2.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# %%writefile 102303735.py
# Name: Vanshika Saini
# Roll Number: 102303735
# Assignment: Mashup Program 1

import sys
import os
import yt_dlp
from pydub import AudioSegment

def download_videos(singer, num_videos):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': 'downloads/%(title)s.%(ext)s'
    }

    if not os.path.exists("downloads"):
        os.makedirs("downloads")

    search_url = f"ytsearch{num_videos}:{singer} songs"

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([search_url])

def convert_and_trim(duration):
    output_files = []

    for file in os.listdir("downloads"):
        if file.endswith(('.mp3', '.m4a', '.webm')):
            file_path = os.path.join("downloads", file)
            audio = AudioSegment.from_file(file_path)
            trimmed = audio[:duration * 1000]

            output_name = file.split('.')[0] + "_trimmed.mp3"
            trimmed.export(output_name, format="mp3")
            output_files.append(output_name)

    return output_files

def merge_audios(audio_files, output_file):
    combined = AudioSegment.empty()

    for file in audio_files:
        audio = AudioSegment.from_mp3(file)
        combined += audio

    combined.export(output_file, format="mp3")

def main():
    if len(sys.argv) != 5:
        print("Usage: python <program.py> <SingerName> <NumberOfVideos> <AudioDuration> <OutputFileName>")
        sys.exit(1)

    singer = sys.argv[1]
    num_videos = int(sys.argv[2])
    duration = int(sys.argv[3])
    output_file = sys.argv[4]

    if num_videos <= 10:
        print("Number of videos must be greater than 10")
        sys.exit(1)

    if duration <= 20:
        print("Duration must be greater than 20 seconds")
        sys.exit(1)

    try:
        print("Downloading videos...")
        download_videos(singer, num_videos)

        print("Converting and trimming...")
        audio_files = convert_and_trim(duration)

        print("Merging files...")
        merge_audios(audio_files, output_file)

        print("Mashup created successfully!")

    except Exception as e:
        print("Error occurred:", e)

if __name__ == "__main__":
    main()
# Out:
# Overwriting 102303735.py

# %%
# !python 102303735.py "Sharry Maan" 20 30 102303735-output.mp3
# Out:
# Downloading videos...
# [youtube:search] Extracting URL: ytsearch20:Sharry Maan songs
# [download] Downloading playlist: Sharry Maan songs
# [youtube:search] query "Sharry Maan songs": Downloading web client config
# [youtube:search] query "Sharry Maan songs" page 1: Downloading API JSON
# [youtube:search] Playlist Sharry Maan songs: Downloading 20 items of 20
# [download] Downloading item 1 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1ksdcHn8qgc
# [youtube] 1ksdcHn8qgc: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 1ksdcHn8qgc: Downloading android vr player API JSON
# [info] 1ksdcHn8qgc: Downloading 1 format(s): 251
# [download] Destination: downloads/Best Of Sharry Mann ｜ Audio Jukebox ｜ Punjabi Songs Collection ｜ Speed Records.webm
# [download] 100% of   47.42MiB in 00:00:01 at 42.52MiB/s
# [download] Downloading item 2 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LIG3Yl5pZ1Y
# [youtube] LIG3Yl5pZ1Y: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] LIG3Yl5pZ1Y: Downloading android vr player API JSON
# [info] LIG3Yl5pZ1Y: Downloading 1 format(s): 251
# [download] Destination: downloads/Bhul Jayi Na (Full Song) ｜ Sharry Maan ｜ Latest Punjabi Song 2017 ｜ Speed Records.webm
# [download] 100% of    4.13MiB in 00:00:00 at 19.23MiB/s
# [download] Downloading item 3 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JoxkEJ-Dwjs
# [youtube] JoxkEJ-Dwjs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] JoxkEJ-Dwjs: Downloading android vr player API JSON
# [info] JoxkEJ-Dwjs: Downloading 1 format(s): 251
# [download] Destination: downloads/Sharry maan old song ｜ Sharry maan all song｜ Sharry maan top7 song ｜ Sharry maan sad song #1million.webm
# [download] 100% of   25.57MiB in 00:00:00 at 51.25MiB/s
# [download] Downloading item 4 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=avX2EqHU2qE
# [youtube] avX2EqHU2qE: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] avX2EqHU2qE: Downloading android vr player API JSON
# [info] avX2EqHU2qE: Downloading 1 format(s): 251
# [download] Destination: downloads/MERI BEBE ｜ AUDIO JUKEBOX ｜ SHARRY MANN ｜ OFFICIAL JUKEBOX 2015.webm
# [download] 100% of   51.44MiB in 00:00:02 at 17.45MiB/s
# [download] Downloading item 5 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zPHms40Ws38
# [youtube] zPHms40Ws38: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] zPHms40Ws38: Downloading android vr player API JSON
# [info] zPHms40Ws38: Downloading 1 format(s): 251
# [download] Destination: downloads/Latest Punjabi Song 2017 ｜ Chandigarh Waliye ｜ Sharry Mann ｜ Lyrical Video.webm
# [download] 100% of    3.31MiB in 00:00:00 at 25.15MiB/s
# [download] Downloading item 6 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lKB2AoDopM4
# [youtube] lKB2AoDopM4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] lKB2AoDopM4: Downloading android vr player API JSON
# [info] lKB2AoDopM4: Downloading 1 format(s): 251
# [download] Destination: downloads/Sohne Mukhde Da (Official Video) ｜ Sharry Mann ｜ Aate Di Chiri  ｜ Latest Punjabi Songs 2012.webm
# [download] 100% of    4.11MiB in 00:00:00 at 23.55MiB/s
# [download] Downloading item 7 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3AwJ5TWkhO4
# [youtube] 3AwJ5TWkhO4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 3AwJ5TWkhO4: Downloading android vr player API JSON
# [info] 3AwJ5TWkhO4: Downloading 1 format(s): 251
# [download] Destination: downloads/Yaari Da Vasta Reloaded.webm
# [download] 100% of    4.81MiB in 00:00:00 at 21.55MiB/s
# [download] Downloading item 8 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4KOqzXHXsWI
# [youtube] 4KOqzXHXsWI: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 4KOqzXHXsWI: Downloading android vr player API JSON
# [info] 4KOqzXHXsWI: Downloading 1 format(s): 251
# [download] Destination: downloads/Disk Ch Kali (Full Official Video) ｜ Sharry Mann ｜ Latest Punjabi Song 2018 ｜ Speed Records.webm
# [download] 100% of    3.24MiB in 00:00:00 at 20.45MiB/s
# [download] Downloading item 9 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tR6XkXy-gjY
# [youtube] tR6XkXy-gjY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] tR6XkXy-gjY: Downloading android vr player API JSON
# [info] tR6XkXy-gjY: Downloading 1 format(s): 251
# [download] Destination: downloads/Yankne (Official Video) ｜ Sharry Maan ｜ New Punjabi Song 2012 ｜ Punjabi Songs ｜ Speed Records.webm
# [download] 100% of    3.50MiB in 00:00:00 at 15.81MiB/s
# [download] Downloading item 10 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=o_4Guei57d4
# [youtube] o_4Guei57d4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] o_4Guei57d4: Downloading android vr player API JSON
# [info] o_4Guei57d4: Downloading 1 format(s): 251
# [download] Destination: downloads/Boomerang (Official Video ) - Sharry Maan ｜ Gora ｜ Nick Dhammu ｜ Rupan Bal.webm
# [download] 100% of    3.23MiB in 00:00:00 at 17.64MiB/s
# [download] Downloading item 11 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0qimBipiCV8
# [youtube] 0qimBipiCV8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 0qimBipiCV8: Downloading android vr player API JSON
# [info] 0qimBipiCV8: Downloading 1 format(s): 251
# [download] Destination: downloads/Dilwale (Official Video) Sharry Maan  ｜ DILWALE The Album ｜ Latest Punjabi Songs.webm
# [download] 100% of    4.78MiB in 00:00:00 at 15.57MiB/s
# [download] Downloading item 12 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=f2LI9TqnLAA
# [youtube] f2LI9TqnLAA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] f2LI9TqnLAA: Downloading android vr player API JSON
# [info] f2LI9TqnLAA: Downloading 1 format(s): 251
# [download] Destination: downloads/Aatte Di Chiri (Full Audio Song) ｜ Sharry Mann ｜ Full Audio Song ｜ Speed Records.webm
# [download] 100% of    6.22MiB in 00:00:00 at 29.08MiB/s
# [download] Downloading item 13 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=THEwbUfdDBg
# [youtube] THEwbUfdDBg: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] THEwbUfdDBg: Downloading android vr player API JSON
# [info] THEwbUfdDBg: Downloading 1 format(s): 251
# [download] Destination: downloads/Sharry Mann - Meri Jindagi Bana De ｜ Official Lyrical Video ｜ New Punjabi Songs 2016.webm
# [download] 100% of    2.78MiB in 00:00:00 at 17.55MiB/s
# [download] Downloading item 14 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iiQmg8Sldu8
# [youtube] iiQmg8Sldu8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] iiQmg8Sldu8: Downloading android vr player API JSON
# [info] iiQmg8Sldu8: Downloading 1 format(s): 251
# [download] Destination: downloads/Yaar Anmulle (Full Video) ｜ Sharry Mann ｜ Babbu ｜ Latest Punjabi Songs ｜ Speed Records Classic Hitz.webm
# [download] 100% of    4.05MiB in 00:00:00 at 24.20MiB/s
# [download] Downloading item 15 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Rjt-xnANSfA
# [youtube] Rjt-xnANSfA: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Rjt-xnANSfA: Downloading android vr player API JSON
# [info] Rjt-xnANSfA: Downloading 1 format(s): 251
# [download] Destination: downloads/SHAKTI WATER (FULL VIDEO) SHARRY MAAN ｜ MISTA BAAZ  ｜ LATEST PUNJABI SONGS 2022.webm
# [download] 100% of    3.36MiB in 00:00:00 at 21.02MiB/s
# [download] Downloading item 16 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Kd57YHWqrsI
# [youtube] Kd57YHWqrsI: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Kd57YHWqrsI: Downloading android vr player API JSON
# [info] Kd57YHWqrsI: Downloading 1 format(s): 251
# [download] Destination: downloads/Hostel Sharry Mann Video Song ｜ Parmish Verma ｜ Mista Baaz ｜ New Punjabi Song 2017 ｜ Punjabi Song.webm
# [download] 100% of    5.27MiB in 00:00:00 at 34.66MiB/s
# [download] Downloading item 17 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PDlw1Tn-PVk
# [youtube] PDlw1Tn-PVk: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] PDlw1Tn-PVk: Downloading android vr player API JSON
# [info] PDlw1Tn-PVk: Downloading 1 format(s): 251
# [download] Destination: downloads/CUTE MUNDA - Sharry Mann (Full Video Song) ｜ Parmish Verma ｜ New Punjabi Songs.webm
# [download] 100% of    3.89MiB in 00:00:00 at 25.05MiB/s
# [download] Downloading item 18 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hheLRMkUdZ4
# [youtube] hheLRMkUdZ4: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] hheLRMkUdZ4: Downloading android vr player API JSON
# [info] hheLRMkUdZ4: Downloading 1 format(s): 251
# [download] Destination: downloads/Putt Mehlan De ( Official Video ) ｜ Sharry Maan ｜ STILL - Album ｜ Latest Punjabi Songs 2023.webm
# [download] 100% of    6.06MiB in 00:00:00 at 30.38MiB/s
# [download] Downloading item 19 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tTHp2GxenIQ
# [youtube] tTHp2GxenIQ: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] tTHp2GxenIQ: Downloading android vr player API JSON
# [info] tTHp2GxenIQ: Downloading 1 format(s): 251
# [download] Destination: downloads/Sharry Maan Top 10 Hits (Audio Jukebox) ｜ Latest Punjabi Songs 2025 ｜ New Punjabi Songs.webm
# [download] 100% of   43.10MiB in 00:00:01 at 42.35MiB/s
# [download] Downloading item 20 of 20
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hzTg4zPBtDU
# [youtube] hzTg4zPBtDU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] hzTg4zPBtDU: Downloading android vr player API JSON
# [info] hzTg4zPBtDU: Downloading 1 format(s): 251
# [download] Destination: downloads/＂3 Peg Sharry Mann＂ (Full Video) ｜ Mista Baaz ｜ Parmish Verma ｜ Ravi Raj ｜ Latest Punjabi Songs 2016.webm
# [download] 100% of    4.57MiB in 00:00:00 at 27.43MiB/s
# [download] Finished downloading playlist: Sharry Maan songs
# Converting and trimming...
# Merging files...
# Mashup created successfully!

# %%
# !ls
# Out:
#  102303735-output.mp3
#  102303735.py
# '＂3 Peg Sharry Mann＂ (Full Video) ｜ Mista Baaz ｜ Parmish Verma ｜ Ravi Raj ｜ Latest Punjabi Songs 2016_trimmed.mp3'
# 'Aatte Di Chiri (Full Audio Song) ｜ Sharry Mann ｜ Full Audio Song ｜ Speed Records_trimmed.mp3'
# 'Best Of Sharry Mann ｜ Audio Jukebox ｜ Punjabi Songs Collection ｜ Speed Records_trimmed.mp3'
# 'Bhul Jayi Na (Full Song) ｜ Sharry Maan ｜ Latest Punjabi Song 2017 ｜ Speed Records_trimmed.mp3'
# 'Boomerang (Official Video ) - Sharry Maan ｜ Gora ｜ Nick Dhammu ｜ Rupan Bal_trimmed.mp3'
# 'CUTE MUNDA - Sharry Mann (Full Video Song) ｜ Parmish Verma ｜ New Punjabi Songs_trimmed.mp3'
# 'Dilwale (Official Video) Sharry Maan  ｜ DILWALE The Album ｜ Latest Punjabi Songs_trimmed.mp3'
# 'Disk Ch Kali (Full Official Video) ｜ Sharry Mann ｜ Latest Punjabi Song 2018 ｜ Speed Records_trimmed.mp3'
#  downloads
# 'Hostel Sharry Mann Video Song ｜ Parmish Verma ｜ Mista Baaz ｜ New Punjabi Song 2017 ｜ Punjabi Song_trimmed.mp3'
# 'Latest Punjabi Song 2017 ｜ Chandigarh Waliye ｜ Sharry Mann ｜ Lyrical Video_trimmed.mp3'
# 'MERI BEBE ｜ AUDIO JUKEBOX ｜ SHARRY MANN ｜ OFFICIAL JUKEBOX 2015_trimmed.mp3'
# 'Putt Mehlan De ( Official Video ) ｜ Sharry Maan ｜ STILL - Album ｜ Latest Punjabi Songs 2023_trimmed.mp3'
#  sample_data
# 'SHAKTI WATER (FULL VIDEO) SHARRY MAAN ｜ MISTA BAAZ  ｜ LATEST PUNJABI SONGS 2022_trimmed.mp3'
# 'Sharry maan old song ｜ Sharry maan all song｜ Sharry maan top7 song ｜ Sharry maan sad song #1million_trimmed.mp3'
# 'Sharry Maan Top 10 Hits (Audio Jukebox) ｜ Latest Punjabi Songs 2025 ｜ New Punjabi Songs_trimmed.mp3'
# 'Sharry Mann - Meri Jindagi Bana De ｜ Official Lyrical Video ｜ New Punjabi Songs 2016_trimmed.mp3'
# 'Sohne Mukhde Da (Official Video) ｜ Sharry Mann ｜ Aate Di Chiri  ｜ Latest Punjabi Songs 2012_trimmed.mp3'
# 'Yaar Anmulle (Full Video) ｜ Sharry Mann ｜ Babbu ｜ Latest Punjabi Songs ｜ Speed Records Classic Hitz_trimmed.mp3'
# 'Yaari Da Vasta Reloaded_trimmed.mp3'
# 'Yankne (Official Video) ｜ Sharry Maan ｜ New Punjabi Song 2012 ｜ Punjabi Songs ｜ Speed Records_trimmed.mp3'

# %%
# !ls downloads
# Out:
# '＂3 Peg Sharry Mann＂ (Full Video) ｜ Mista Baaz ｜ Parmish Verma ｜ Ravi Raj ｜ Latest Punjabi Songs 2016.webm'
# 'Aatte Di Chiri (Full Audio Song) ｜ Sharry Mann ｜ Full Audio Song ｜ Speed Records.webm'
# 'Best Of Sharry Mann ｜ Audio Jukebox ｜ Punjabi Songs Collection ｜ Speed Records.webm'
# 'Bhul Jayi Na (Full Song) ｜ Sharry Maan ｜ Latest Punjabi Song 2017 ｜ Speed Records.webm'
# 'Boomerang (Official Video ) - Sharry Maan ｜ Gora ｜ Nick Dhammu ｜ Rupan Bal.webm'
# 'CUTE MUNDA - Sharry Mann (Full Video Song) ｜ Parmish Verma ｜ New Punjabi Songs.webm'
# 'Dilwale (Official Video) Sharry Maan  ｜ DILWALE The Album ｜ Latest Punjabi Songs.webm'
# 'Disk Ch Kali (Full Official Video) ｜ Sharry Mann ｜ Latest Punjabi Song 2018 ｜ Speed Records.webm'
# 'Hostel Sharry Mann Video Song ｜ Parmish Verma ｜ Mista Baaz ｜ New Punjabi Song 2017 ｜ Punjabi Song.webm'
# 'Latest Punjabi Song 2017 ｜ Chandigarh Waliye ｜ Sharry Mann ｜ Lyrical Video.webm'
# 'MERI BEBE ｜ AUDIO JUKEBOX ｜ SHARRY MANN ｜ OFFICIAL JUKEBOX 2015.webm'
# 'Putt Mehlan De ( Official Video ) ｜ Sharry Maan ｜ STILL - Album ｜ Latest Punjabi Songs 2023.webm'
# 'SHAKTI WATER (FULL VIDEO) SHARRY MAAN ｜ MISTA BAAZ  ｜ LATEST PUNJABI SONGS 2022.webm'
# 'Sharry maan old song ｜ Sharry maan all song｜ Sharry maan top7 song ｜ Sharry maan sad song #1million.webm'
# 'Sharry Maan Top 10 Hits (Audio Jukebox) ｜ Latest Punjabi Songs 2025 ｜ New Punjabi Songs.webm'
# 'Sharry Mann - Meri Jindagi Bana De ｜ Official Lyrical Video ｜ New Punjabi Songs 2016.webm'
# 'Sohne Mukhde Da (Official Video) ｜ Sharry Mann ｜ Aate Di Chiri  ｜ Latest Punjabi Songs 2012.webm'
# 'Yaar Anmulle (Full Video) ｜ Sharry Mann ｜ Babbu ｜ Latest Punjabi Songs ｜ Speed Records Classic Hitz.webm'
# 'Yaari Da Vasta Reloaded.webm'
# 'Yankne (Official Video) ｜ Sharry Maan ｜ New Punjabi Song 2012 ｜ Punjabi Songs ｜ Speed Records.webm'

# %%
from google.colab import files
files.download("102303735-output.mp3")

# %%
files.download("102303735.py")
